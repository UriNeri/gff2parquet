# %% [markdown]
# # GFF2Parquet Testing Notebook
# This notebook demonstrates the various features of the `gff2parquet` CLI tool.

# %% [markdown]
# ## Setup and Data Paths

# %%
from pathlib import Path
import subprocess
import sys
import os
import polars as pl
import pyarrow.parquet as pq


# Define data paths
DATA_DIR = Path("./")
GFF_DIR = DATA_DIR / "downloaded_gff"
FASTA_DIR = DATA_DIR / "downloaded_fasta"
OUTPUT_DIR = DATA_DIR / "test_outputs"

# Create output directory
OUTPUT_DIR.mkdir(exist_ok=True, parents=True)

# print(f"current directory: {os.getcwd()}")
# Helper function to run CLI commands
def run_gff2parquet(args):
    """Run gff2parquet command and print output."""
    cmd = ["gff2parquet"] + args
    print(f"Running: {' '.join(cmd)}")
    result = subprocess.run(cmd, capture_output=True, text=True)
    if result.stdout:
        print(result.stdout)
    if result.stderr:
        print(result.stderr, file=sys.stderr)
    if result.returncode != 0:
        print(f"Command failed with return code {result.returncode}", file=sys.stderr)
    return result

# %% [markdown]
# ## 1. Print Command - Inspect GFF Files
# Let's start by examining the first GFF file to understand its structure.

# %%
# Print first 10 rows of a GFF file
run_gff2parquet([
    "print",
    str(GFF_DIR / "groupI_GCA_000859985.2.gff"),
    "--head", "10",
    "--format", "table"
])
# Out:
# Running: gff2parquet print downloaded_gff/groupI_GCA_000859985.2.gff --head 10 --format table
# | seqid      | source  | type            | start | end    | score | strand | phase | attributes                                                                                                 | source_file                               |
# | ---        | ---     | ---             | ---   | ---    | ---   | ---    | ---   | ---                                                                                                        | ---                                       |
# | str        | str     | str             | u32   | u32    | f32   | str    | u32   | list[struct[2]]                                                                                            | str                                       |
# |------------|---------|-----------------|-------|--------|-------|--------|-------|------------------------------------------------------------------------------------------------------------|-------------------------------------------|
# | JN555585.1 | Genbank | region          | 1     | 152222 | null  | +      | null  | [{"ID","JN555585.1:1..152222"}, {"Dbxref","taxon:10298"}, … {"strain","17"}]                               | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | inverted_repeat | 1     | 9213   | null  | +      | null  | [{"ID","id-JN555585.1:1..9213"}, {"Note","TRL%3B inverted repeat flanking UL"}, … {"rpt_type","inverted"}] | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene            | 1     | 7569   | null  | -      | null  | [{"ID","gene-LAT"}, {"Name","LAT"}, … {"start_range",".,1"}]                                               | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | ncRNA           | 1     | 7569   | null  | -      | null  | [{"ID","rna-LAT"}, {"Parent","gene-LAT"}, … {"start_range",".,1"}]                                         | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | exon            | 6910  | 7569   | null  | -      | null  | [{"ID","exon-LAT-1"}, {"Parent","rna-LAT"}, … {"product","LAT"}]                                           | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | exon            | 1     | 4953   | null  | -      | null  | [{"ID","exon-LAT-2"}, {"Parent","rna-LAT"}, … {"start_range",".,1"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | repeat_region   | 1     | 399    | null  | +      | null  | [{"ID","id-JN555585.1:1..399"}, {"Note","'a' sequence"}, … {"rpt_type","terminal"}]                        | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | repeat_region   | 98    | 320    | null  | +      | null  | [{"ID","id-JN555585.1:98..320"}, {"Note","'a' sequence reiteration set"}, … {"rpt_unit_range","98..109"}]  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene            | 513   | 1540   | null  | +      | null  | [{"ID","gene-RL1"}, {"Name","RL1"}, … {"gene_biotype","protein_coding"}]                                   | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS             | 513   | 1259   | null  | +      | 0     | [{"ID","cds-AEQ77029.1"}, {"Parent","gene-RL1"}, … {"protein_id","AEQ77029.1"}]                            | downloaded_gff/groupI_GCA_000859985.2.gff |
# Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
# CompletedProcess(args=['gff2parquet', 'print', 'downloaded_gff/groupI_GCA_000859985.2.gff', '--head', '10', '--format', 'table'], returncode=0, stdout='| seqid      | source  | type            | start | end    | score | strand | phase | attributes                                                                                                 | source_file                               |\n| ---        | ---     | ---             | ---   | ---    | ---   | ---    | ---   | ---                                                                                                        | ---                                       |\n| str        | str     | str             | u32   | u32    | f32   | str    | u32   | list[struct[2]]                                                                                            | str                                       |\n|------------|---------|-----------------|-------|--------|-------|--------|-------|------------------------------------------------------------------------------------------------------------|-------------------------------------------|\n| JN555585.1 | Genbank | region          | 1     | 152222 | null  | +      | null  | [{"ID","JN555585.1:1..152222"}, {"Dbxref","taxon:10298"}, … {"strain","17"}]                               | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | inverted_repeat | 1     | 9213   | null  | +      | null  | [{"ID","id-JN555585.1:1..9213"}, {"Note","TRL%3B inverted repeat flanking UL"}, … {"rpt_type","inverted"}] | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | gene            | 1     | 7569   | null  | -      | null  | [{"ID","gene-LAT"}, {"Name","LAT"}, … {"start_range",".,1"}]                                               | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | ncRNA           | 1     | 7569   | null  | -      | null  | [{"ID","rna-LAT"}, {"Parent","gene-LAT"}, … {"start_range",".,1"}]                                         | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | exon            | 6910  | 7569   | null  | -      | null  | [{"ID","exon-LAT-1"}, {"Parent","rna-LAT"}, … {"product","LAT"}]                                           | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | exon            | 1     | 4953   | null  | -      | null  | [{"ID","exon-LAT-2"}, {"Parent","rna-LAT"}, … {"start_range",".,1"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | repeat_region   | 1     | 399    | null  | +      | null  | [{"ID","id-JN555585.1:1..399"}, {"Note","\'a\' sequence"}, … {"rpt_type","terminal"}]                        | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | repeat_region   | 98    | 320    | null  | +      | null  | [{"ID","id-JN555585.1:98..320"}, {"Note","\'a\' sequence reiteration set"}, … {"rpt_unit_range","98..109"}]  | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | gene            | 513   | 1540   | null  | +      | null  | [{"ID","gene-RL1"}, {"Name","RL1"}, … {"gene_biotype","protein_coding"}]                                   | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | CDS             | 513   | 1259   | null  | +      | 0     | [{"ID","cds-AEQ77029.1"}, {"Parent","gene-RL1"}, … {"protein_id","AEQ77029.1"}]                            | downloaded_gff/groupI_GCA_000859985.2.gff |\n', stderr="Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'\nScanning: downloaded_gff/groupI_GCA_000859985.2.gff\n")

# %% [markdown]
# ### Show statistics about feature types
# (in addition to printing)

# %%
run_gff2parquet([
    "print",
    str(GFF_DIR / "groupI_GCA_000859985.2.gff"),
    "--stats",
])
# Out:
# Running: gff2parquet print downloaded_gff/groupI_GCA_000859985.2.gff --stats
# | seqid      | source  | type                  | start  | end    | score | strand | phase | attributes                                                                                                                       | source_file                               |
# | ---        | ---     | ---                   | ---    | ---    | ---   | ---    | ---   | ---                                                                                                                              | ---                                       |
# | str        | str     | str                   | u32    | u32    | f32   | str    | u32   | list[struct[2]]                                                                                                                  | str                                       |
# |------------|---------|-----------------------|--------|--------|-------|--------|-------|----------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------|
# | JN555585.1 | Genbank | region                | 1      | 152222 | null  | +      | null  | [{"ID","JN555585.1:1..152222"}, {"Dbxref","taxon:10298"}, … {"strain","17"}]                                                     | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | inverted_repeat       | 1      | 9213   | null  | +      | null  | [{"ID","id-JN555585.1:1..9213"}, {"Note","TRL%3B inverted repeat flanking UL"}, … {"rpt_type","inverted"}]                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 1      | 7569   | null  | -      | null  | [{"ID","gene-LAT"}, {"Name","LAT"}, … {"start_range",".,1"}]                                                                     | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | ncRNA                 | 1      | 7569   | null  | -      | null  | [{"ID","rna-LAT"}, {"Parent","gene-LAT"}, … {"start_range",".,1"}]                                                               | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | exon                  | 6910   | 7569   | null  | -      | null  | [{"ID","exon-LAT-1"}, {"Parent","rna-LAT"}, … {"product","LAT"}]                                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | exon                  | 1      | 4953   | null  | -      | null  | [{"ID","exon-LAT-2"}, {"Parent","rna-LAT"}, … {"start_range",".,1"}]                                                             | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | repeat_region         | 1      | 399    | null  | +      | null  | [{"ID","id-JN555585.1:1..399"}, {"Note","'a' sequence"}, … {"rpt_type","terminal"}]                                              | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | repeat_region         | 98     | 320    | null  | +      | null  | [{"ID","id-JN555585.1:98..320"}, {"Note","'a' sequence reiteration set"}, … {"rpt_unit_range","98..109"}]                        | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 513    | 1540   | null  | +      | null  | [{"ID","gene-RL1"}, {"Name","RL1"}, … {"gene_biotype","protein_coding"}]                                                         | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 513    | 1259   | null  | +      | 0     | [{"ID","cds-AEQ77029.1"}, {"Parent","gene-RL1"}, … {"protein_id","AEQ77029.1"}]                                                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | repeat_region         | 988    | 1040   | null  | +      | null  | [{"ID","id-RL1"}, {"Note","RL reiteration set 6"}, … {"rpt_unit_range","988..996"}]                                              | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 1535   | 1540   | null  | +      | null  | [{"ID","id-RL1-2"}, {"Parent","gene-RL1"}, … {"regulatory_class","polyA_signal_sequence"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 2087   | 5699   | null  | +      | null  | [{"ID","gene-RL2"}, {"Name","RL2"}, … {"gene_biotype","protein_coding"}]                                                         | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | mRNA                  | 2114   | 5699   | null  | +      | null  | [{"ID","rna-RL2"}, {"Parent","gene-RL2"}, … {"product","ubiquitin E3 ligase ICP0"}]                                              | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | exon                  | 2114   | 2318   | null  | +      | null  | [{"ID","exon-RL2-1"}, {"Parent","rna-RL2"}, … {"product","ubiquitin E3 ligase ICP0"}]                                            | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | exon                  | 3084   | 3750   | null  | +      | null  | [{"ID","exon-RL2-2"}, {"Parent","rna-RL2"}, … {"product","ubiquitin E3 ligase ICP0"}]                                            | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | exon                  | 3887   | 5699   | null  | +      | null  | [{"ID","exon-RL2-3"}, {"Parent","rna-RL2"}, … {"product","ubiquitin E3 ligase ICP0"}]                                            | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 2262   | 2318   | null  | +      | 0     | [{"ID","cds-AEQ77030.1"}, {"Parent","rna-RL2"}, … {"protein_id","AEQ77030.1"}]                                                   | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 3084   | 3750   | null  | +      | 0     | [{"ID","cds-AEQ77030.1"}, {"Parent","rna-RL2"}, … {"protein_id","AEQ77030.1"}]                                                   | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 3887   | 5490   | null  | +      | 2     | [{"ID","cds-AEQ77030.1"}, {"Parent","rna-RL2"}, … {"protein_id","AEQ77030.1"}]                                                   | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | repeat_region         | 2466   | 2624   | null  | +      | null  | [{"ID","id-RL2"}, {"Note","RL reiteration set 5"}, … {"rpt_unit_range","2466..2519"}]                                            | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | TATA_box              | 2087   | 2092   | null  | +      | null  | [{"ID","id-RL2-2"}, {"Parent","gene-RL2"}, … {"regulatory_class","TATA_box"}]                                                    | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 5677   | 5682   | null  | +      | null  | [{"ID","id-RL2-3"}, {"Parent","gene-RL2"}, … {"regulatory_class","polyA_signal_sequence"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | repeat_region         | 5732   | 5878   | null  | +      | null  | [{"ID","id-JN555585.1:5732..5878"}, {"Note","RL reiteration set 4"}, … {"rpt_unit_range","5732..5747"}]                          | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | TATA_box              | 7592   | 7597   | null  | -      | null  | [{"ID","id-JN555585.1:7592..7597"}, {"gbkey","regulatory"}, {"regulatory_class","TATA_box"}]                                     | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | repeat_region         | 8554   | 8585   | null  | +      | null  | [{"ID","id-JN555585.1:8554..8585"}, {"Note","RL reiteration set 3"}, … {"rpt_unit_range","8554..8558"}]                          | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | repeat_region         | 8806   | 8826   | null  | +      | null  | [{"ID","id-JN555585.1:8806..8826"}, {"Note","RL reiteration set 2"}, … {"rpt_unit_range","8806..8808"}]                          | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | repeat_region         | 9033   | 9213   | null  | +      | null  | [{"ID","id-JN555585.1:9033..9213"}, {"Note","RL reiteration set 1"}, … {"rpt_unit_range","9033..9049"}]                          | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | sequence_feature      | 9214   | 117160 | null  | +      | null  | [{"ID","id-JN555585.1:9214..117160"}, {"Note","UL%3B long unique region"}, {"gbkey","misc_feature"}]                             | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 9338   | 10949  | null  | +      | null  | [{"ID","gene-UL1"}, {"Name","UL1"}, … {"gene_biotype","protein_coding"}]                                                         | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 9338   | 10012  | null  | +      | 0     | [{"ID","cds-AEQ77031.1"}, {"Parent","gene-UL1"}, … {"protein_id","AEQ77031.1"}]                                                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 9885   | 10949  | null  | +      | null  | [{"ID","gene-UL2"}, {"Name","UL2"}, … {"gene_biotype","protein_coding"}]                                                         | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 9885   | 10889  | null  | +      | 0     | [{"ID","cds-AEQ77032.1"}, {"Parent","gene-UL2"}, … {"protein_id","AEQ77032.1"}]                                                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 10944  | 10949  | null  | +      | null  | [{"ID","id-JN555585.1:10944..10949"}, {"Note","UL1%2C UL2"}, … {"regulatory_class","polyA_signal_sequence"}]                     | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 10991  | 11721  | null  | +      | null  | [{"ID","gene-UL3"}, {"Name","UL3"}, … {"gene_biotype","protein_coding"}]                                                         | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 10991  | 11665  | null  | +      | 0     | [{"ID","cds-AEQ77033.1"}, {"Parent","gene-UL3"}, … {"protein_id","AEQ77033.1"}]                                                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 11716  | 11721  | null  | +      | null  | [{"ID","id-UL3"}, {"Parent","gene-UL3"}, … {"regulatory_class","polyA_signal_sequence"}]                                         | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 11754  | 15132  | null  | -      | null  | [{"ID","gene-UL5"}, {"Name","UL5"}, … {"gene_biotype","protein_coding"}]                                                         | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 12484  | 15132  | null  | -      | 0     | [{"ID","cds-AEQ77035.1"}, {"Parent","gene-UL5"}, … {"protein_id","AEQ77035.1"}]                                                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 11754  | 12423  | null  | -      | null  | [{"ID","gene-UL4"}, {"Name","UL4"}, … {"gene_biotype","protein_coding"}]                                                         | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 11824  | 12423  | null  | -      | 0     | [{"ID","cds-AEQ77034.1"}, {"Parent","gene-UL4"}, … {"protein_id","AEQ77034.1"}]                                                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 11754  | 11759  | null  | -      | null  | [{"ID","id-JN555585.1:11754..11759"}, {"Note","UL4%2C UL5"}, … {"regulatory_class","polyA_signal_sequence"}]                     | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 15131  | 18041  | null  | +      | null  | [{"ID","gene-UL6"}, {"Name","UL6"}, … {"gene_biotype","protein_coding"}]                                                         | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 15131  | 17161  | null  | +      | 0     | [{"ID","cds-AEQ77036.1"}, {"Parent","gene-UL6"}, … {"protein_id","AEQ77036.1"}]                                                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 17136  | 18041  | null  | +      | null  | [{"ID","gene-UL7"}, {"Name","UL7"}, … {"gene_biotype","protein_coding"}]                                                         | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 17136  | 18026  | null  | +      | 0     | [{"ID","cds-AEQ77037.1"}, {"Parent","gene-UL7"}, … {"protein_id","AEQ77037.1"}]                                                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 18036  | 18041  | null  | +      | null  | [{"ID","id-JN555585.1:18036..18041"}, {"Note","UL6%2C UL7"}, … {"regulatory_class","polyA_signal_sequence"}]                     | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 18211  | 23260  | null  | -      | null  | [{"ID","gene-UL9"}, {"Name","UL9"}, … {"gene_biotype","protein_coding"}]                                                         | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 20705  | 23260  | null  | -      | 0     | [{"ID","cds-AEQ77039.1"}, {"Parent","gene-UL9"}, … {"protein_id","AEQ77039.1"}]                                                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 18211  | 20477  | null  | -      | null  | [{"ID","gene-UL8"}, {"Name","UL8"}, … {"gene_biotype","protein_coding"}]                                                         | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 18225  | 20477  | null  | -      | 0     | [{"ID","cds-AEQ77038.1"}, {"Parent","gene-UL8"}, … {"protein_id","AEQ77038.1"}]                                                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 18211  | 18216  | null  | -      | null  | [{"ID","id-JN555585.1:18211..18216"}, {"Note","UL8%2C UL9"}, … {"regulatory_class","polyA_signal_sequence"}]                     | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 23205  | 24649  | null  | +      | null  | [{"ID","gene-UL10"}, {"Name","UL10"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 23205  | 24626  | null  | +      | 0     | [{"ID","cds-AEQ77040.1"}, {"Parent","gene-UL10"}, … {"protein_id","AEQ77040.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 24644  | 24649  | null  | +      | null  | [{"ID","id-UL10"}, {"Parent","gene-UL10"}, … {"regulatory_class","polyA_signal_sequence"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 24801  | 28916  | null  | -      | null  | [{"ID","gene-UL14"}, {"Name","UL14"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 28257  | 28916  | null  | -      | 0     | [{"ID","cds-AEQ77044.1"}, {"Parent","gene-UL14"}, … {"protein_id","AEQ77044.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 24801  | 28503  | null  | -      | null  | [{"ID","gene-UL13"}, {"Name","UL13"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 26947  | 28503  | null  | -      | 0     | [{"ID","cds-AEQ77043.1"}, {"Parent","gene-UL13"}, … {"protein_id","AEQ77043.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 24801  | 26888  | null  | -      | null  | [{"ID","gene-UL12"}, {"Name","UL12"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 25008  | 26888  | null  | -      | 0     | [{"ID","cds-AEQ77042.1"}, {"Parent","gene-UL12"}, … {"protein_id","AEQ77042.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 24801  | 25092  | null  | -      | null  | [{"ID","gene-UL11"}, {"Name","UL11"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 24802  | 25092  | null  | -      | 0     | [{"ID","cds-AEQ77041.1"}, {"Parent","gene-UL11"}, … {"protein_id","AEQ77041.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 24801  | 24806  | null  | -      | null  | [{"ID","id-JN555585.1:24801..24806"}, {"Note","UL11%2C UL12%2C UL13%2C UL14"}, … {"regulatory_class","polyA_signal_sequence"}]   | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 29021  | 34826  | null  | +      | null  | [{"ID","gene-UL15"}, {"Name","UL15"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 29021  | 30049  | null  | +      | 0     | [{"ID","cds-AEQ77045.1"}, {"Parent","gene-UL15"}, … {"protein_id","AEQ77045.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 33636  | 34814  | null  | +      | 0     | [{"ID","cds-AEQ77045.1"}, {"Parent","gene-UL15"}, … {"protein_id","AEQ77045.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 34821  | 34826  | null  | +      | null  | [{"ID","id-UL15"}, {"Parent","gene-UL15"}, … {"regulatory_class","polyA_signal_sequence"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 30174  | 33498  | null  | -      | null  | [{"ID","gene-UL17"}, {"Name","UL17"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 31387  | 33498  | null  | -      | 0     | [{"ID","cds-AEQ77047.1"}, {"Parent","gene-UL17"}, … {"protein_id","AEQ77047.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 30174  | 31296  | null  | -      | null  | [{"ID","gene-UL16"}, {"Name","UL16"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 30175  | 31296  | null  | -      | 0     | [{"ID","cds-AEQ77046.1"}, {"Parent","gene-UL16"}, … {"protein_id","AEQ77046.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 30174  | 30179  | null  | -      | null  | [{"ID","id-JN555585.1:30174..30179"}, {"Note","UL16%2C UL17"}, … {"regulatory_class","polyA_signal_sequence"}]                   | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 35024  | 41489  | null  | -      | null  | [{"ID","gene-UL20"}, {"Name","UL20"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 40821  | 41489  | null  | -      | 0     | [{"ID","cds-AEQ77050.1"}, {"Parent","gene-UL20"}, … {"protein_id","AEQ77050.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 35024  | 40529  | null  | -      | null  | [{"ID","gene-UL19"}, {"Name","UL19"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 36405  | 40529  | null  | -      | 0     | [{"ID","cds-AEQ77049.1"}, {"Parent","gene-UL19"}, … {"protein_id","AEQ77049.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 35024  | 36052  | null  | -      | null  | [{"ID","gene-UL18"}, {"Name","UL18"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 35096  | 36052  | null  | -      | 0     | [{"ID","cds-AEQ77048.1"}, {"Parent","gene-UL18"}, … {"protein_id","AEQ77048.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 35024  | 35029  | null  | -      | null  | [{"ID","id-JN555585.1:35024..35029"}, {"Note","UL18%2C UL19%2C UL20"}, … {"regulatory_class","polyA_signal_sequence"}]           | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 35028  | 35033  | null  | -      | null  | [{"ID","id-JN555585.1:35028..35033"}, {"Note","UL18%2C UL19%2C UL20"}, … {"regulatory_class","polyA_signal_sequence"}]           | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 42075  | 43696  | null  | +      | null  | [{"ID","gene-UL21"}, {"Name","UL21"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 42075  | 43682  | null  | +      | 0     | [{"ID","cds-AEQ77051.1"}, {"Parent","gene-UL21"}, … {"protein_id","AEQ77051.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 43691  | 43696  | null  | +      | null  | [{"ID","id-UL21"}, {"Parent","gene-UL21"}, … {"regulatory_class","polyA_signal_sequence"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 43866  | 46383  | null  | -      | null  | [{"ID","gene-UL22"}, {"Name","UL22"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 43867  | 46383  | null  | -      | 0     | [{"ID","cds-AEQ77052.1"}, {"Parent","gene-UL22"}, … {"protein_id","AEQ77052.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 43866  | 43871  | null  | -      | null  | [{"ID","id-UL22"}, {"Parent","gene-UL22"}, … {"regulatory_class","polyA_signal_sequence"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 46609  | 47803  | null  | -      | null  | [{"ID","gene-UL23"}, {"Name","UL23"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 46673  | 47803  | null  | -      | 0     | [{"ID","cds-AEQ77053.1"}, {"Parent","gene-UL23"}, … {"protein_id","AEQ77053.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 46609  | 46614  | null  | -      | null  | [{"ID","id-UL23"}, {"Parent","gene-UL23"}, … {"regulatory_class","polyA_signal_sequence"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 46622  | 46627  | null  | -      | null  | [{"ID","id-UL23-2"}, {"Parent","gene-UL23"}, … {"regulatory_class","polyA_signal_sequence"}]                                     | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 47738  | 52772  | null  | +      | null  | [{"ID","gene-UL24"}, {"Name","UL24"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 47738  | 48547  | null  | +      | 0     | [{"ID","cds-AEQ77054.1"}, {"Parent","gene-UL24"}, … {"protein_id","AEQ77054.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 48814  | 52772  | null  | +      | null  | [{"ID","gene-UL25"}, {"Name","UL25"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 48814  | 50556  | null  | +      | 0     | [{"ID","cds-AEQ77055.1"}, {"Parent","gene-UL25"}, … {"protein_id","AEQ77055.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 50810  | 52772  | null  | +      | null  | [{"ID","gene-UL26"}, {"Name","UL26"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 50810  | 52717  | null  | +      | 0     | [{"ID","cds-AEQ77056.1"}, {"Parent","gene-UL26"}, … {"protein_id","AEQ77056.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 51728  | 52772  | null  | +      | null  | [{"ID","gene-UL26.5"}, {"Name","UL26.5"}, … {"gene_biotype","protein_coding"}]                                                   | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 51728  | 52717  | null  | +      | 0     | [{"ID","cds-AEQ77057.1"}, {"Parent","gene-UL26.5"}, … {"protein_id","AEQ77057.1"}]                                               | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 52767  | 52772  | null  | +      | null  | [{"ID","id-JN555585.1:52767..52772"}, {"Note","UL24%2C UL25%2C UL26%2C UL26.5"}, … {"regulatory_class","polyA_signal_sequence"}] | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 53059  | 58160  | null  | -      | null  | [{"ID","gene-UL28"}, {"Name","UL28"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 55803  | 58160  | null  | -      | 0     | [{"ID","cds-AEQ77059.1"}, {"Parent","gene-UL28"}, … {"protein_id","AEQ77059.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 53059  | 55795  | null  | -      | null  | [{"ID","gene-UL27"}, {"Name","UL27"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 53081  | 55795  | null  | -      | 0     | [{"ID","cds-AEQ77058.1"}, {"Parent","gene-UL27"}, … {"protein_id","AEQ77058.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 53059  | 53064  | null  | -      | null  | [{"ID","id-JN555585.1:53059..53064"}, {"Note","UL27%2C UL28"}, … {"regulatory_class","polyA_signal_sequence"}]                   | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 58410  | 62054  | null  | -      | null  | [{"ID","gene-UL29"}, {"Name","UL29"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 58464  | 62054  | null  | -      | 0     | [{"ID","cds-AEQ77060.1"}, {"Parent","gene-UL29"}, … {"protein_id","AEQ77060.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 58410  | 58415  | null  | -      | null  | [{"ID","id-UL29"}, {"Parent","gene-UL29"}, … {"regulatory_class","polyA_signal_sequence"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | stem_loop             | 62404  | 62547  | null  | +      | null  | [{"ID","id-JN555585.1:62404..62547"}, {"Note","oriL palindrome"}, {"gbkey","stem_loop"}]                                         | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 62807  | 66553  | null  | +      | null  | [{"ID","gene-UL30"}, {"Name","UL30"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 62807  | 66514  | null  | +      | 0     | [{"ID","cds-AEQ77061.1"}, {"Parent","gene-UL30"}, … {"protein_id","AEQ77061.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 66548  | 66553  | null  | +      | null  | [{"ID","id-UL30"}, {"Parent","gene-UL30"}, … {"regulatory_class","polyA_signal_sequence"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 66377  | 69162  | null  | -      | null  | [{"ID","gene-UL32"}, {"Name","UL32"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 67372  | 69162  | null  | -      | 0     | [{"ID","cds-AEQ77063.1"}, {"Parent","gene-UL32"}, … {"protein_id","AEQ77063.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 66377  | 67379  | null  | -      | null  | [{"ID","gene-UL31"}, {"Name","UL31"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 66459  | 67379  | null  | -      | 0     | [{"ID","cds-AEQ77062.1"}, {"Parent","gene-UL31"}, … {"protein_id","AEQ77062.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 66377  | 66382  | null  | -      | null  | [{"ID","id-JN555585.1:66377..66382"}, {"Note","UL31%2C UL32"}, … {"regulatory_class","polyA_signal_sequence"}]                   | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 69161  | 70943  | null  | +      | null  | [{"ID","gene-UL33"}, {"Name","UL33"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 69161  | 69553  | null  | +      | 0     | [{"ID","cds-AEQ77064.1"}, {"Parent","gene-UL33"}, … {"protein_id","AEQ77064.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 69633  | 70943  | null  | +      | null  | [{"ID","gene-UL34"}, {"Name","UL34"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 69633  | 70460  | null  | +      | 0     | [{"ID","cds-AEQ77065.1"}, {"Parent","gene-UL34"}, … {"protein_id","AEQ77065.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 70566  | 70943  | null  | +      | null  | [{"ID","gene-UL35"}, {"Name","UL35"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 70566  | 70904  | null  | +      | 0     | [{"ID","cds-AEQ77066.1"}, {"Parent","gene-UL35"}, … {"protein_id","AEQ77066.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 70938  | 70943  | null  | +      | null  | [{"ID","id-JN555585.1:70938..70943"}, {"Note","UL33%2C UL34%2C UL35"}, … {"regulatory_class","polyA_signal_sequence"}]           | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 70983  | 80468  | null  | -      | null  | [{"ID","gene-UL36"}, {"Name","UL36"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 71049  | 80468  | null  | -      | 0     | [{"ID","cds-AEQ77067.1"}, {"Parent","gene-UL36"}, … {"protein_id","AEQ77067.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 70983  | 70988  | null  | -      | null  | [{"ID","id-UL36"}, {"Parent","gene-UL36"}, … {"regulatory_class","polyA_signal_sequence"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | repeat_region         | 71604  | 71814  | null  | +      | null  | [{"ID","id-JN555585.1:71604..71814"}, {"Note","UL reiteration set 1"}, … {"rpt_unit_range","71604..71609"}]                      | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 80712  | 84084  | null  | -      | null  | [{"ID","gene-UL37"}, {"Name","UL37"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 80713  | 84084  | null  | -      | 0     | [{"ID","cds-AEQ77068.1"}, {"Parent","gene-UL37"}, … {"protein_id","AEQ77068.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 80712  | 80717  | null  | -      | null  | [{"ID","id-UL37"}, {"Parent","gene-UL37"}, … {"regulatory_class","polyA_signal_sequence"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 84531  | 86021  | null  | +      | null  | [{"ID","gene-UL38"}, {"Name","UL38"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 84531  | 85928  | null  | +      | 0     | [{"ID","cds-AEQ77069.1"}, {"Parent","gene-UL38"}, … {"protein_id","AEQ77069.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 86016  | 86021  | null  | +      | null  | [{"ID","id-UL38"}, {"Parent","gene-UL38"}, … {"regulatory_class","polyA_signal_sequence"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 86443  | 90987  | null  | +      | null  | [{"ID","gene-UL39"}, {"Name","UL39"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 86443  | 89856  | null  | +      | 0     | [{"ID","cds-AEQ77070.1"}, {"Parent","gene-UL39"}, … {"protein_id","AEQ77070.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 89925  | 90987  | null  | +      | null  | [{"ID","gene-UL40"}, {"Name","UL40"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 89925  | 90947  | null  | +      | 0     | [{"ID","cds-AEQ77071.1"}, {"Parent","gene-UL40"}, … {"protein_id","AEQ77071.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 90982  | 90987  | null  | +      | null  | [{"ID","id-JN555585.1:90982..90987"}, {"Note","UL39%2C UL40"}, … {"regulatory_class","polyA_signal_sequence"}]                   | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 91115  | 92636  | null  | -      | null  | [{"ID","gene-UL41"}, {"Name","UL41"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 91167  | 92636  | null  | -      | 0     | [{"ID","cds-AEQ77072.1"}, {"Parent","gene-UL41"}, … {"protein_id","AEQ77072.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 91115  | 91120  | null  | -      | null  | [{"ID","id-UL41"}, {"Parent","gene-UL41"}, … {"regulatory_class","polyA_signal_sequence"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 93112  | 94637  | null  | +      | null  | [{"ID","gene-UL42"}, {"Name","UL42"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 93112  | 94578  | null  | +      | 0     | [{"ID","cds-AEQ77073.1"}, {"Parent","gene-UL42"}, … {"protein_id","AEQ77073.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 94632  | 94637  | null  | +      | null  | [{"ID","id-UL42"}, {"Parent","gene-UL42"}, … {"regulatory_class","polyA_signal_sequence"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 94799  | 96068  | null  | +      | null  | [{"ID","gene-UL43"}, {"Name","UL43"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 94799  | 96052  | null  | +      | 0     | [{"ID","cds-AEQ77074.1"}, {"Parent","gene-UL43"}, … {"protein_id","AEQ77074.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 96063  | 96068  | null  | +      | null  | [{"ID","id-UL43"}, {"Parent","gene-UL43"}, … {"regulatory_class","polyA_signal_sequence"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 96312  | 98669  | null  | +      | null  | [{"ID","gene-UL44"}, {"Name","UL44"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 96312  | 97847  | null  | +      | 0     | [{"ID","cds-AEQ77075.1"}, {"Parent","gene-UL44"}, … {"protein_id","AEQ77075.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 98033  | 98669  | null  | +      | null  | [{"ID","gene-UL45"}, {"Name","UL45"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 98033  | 98551  | null  | +      | 0     | [{"ID","cds-AEQ77076.1"}, {"Parent","gene-UL45"}, … {"protein_id","AEQ77076.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 98664  | 98669  | null  | +      | null  | [{"ID","id-JN555585.1:98664..98669"}, {"Note","UL44%2C UL45"}, … {"regulatory_class","polyA_signal_sequence"}]                   | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 98727  | 103117 | null  | -      | null  | [{"ID","gene-UL47"}, {"Name","UL47"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 101036 | 103117 | null  | -      | 0     | [{"ID","cds-AEQ77078.1"}, {"Parent","gene-UL47"}, … {"protein_id","AEQ77078.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 98727  | 100953 | null  | -      | null  | [{"ID","gene-UL46"}, {"Name","UL46"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 98797  | 100953 | null  | -      | 0     | [{"ID","cds-AEQ77077.1"}, {"Parent","gene-UL46"}, … {"protein_id","AEQ77077.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 98727  | 98732  | null  | -      | null  | [{"ID","id-JN555585.1:98727..98732"}, {"Note","UL46%2C UL47"}, … {"regulatory_class","polyA_signal_sequence"}]                   | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 103538 | 105080 | null  | -      | null  | [{"ID","gene-UL48"}, {"Name","UL48"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 103608 | 105080 | null  | -      | 0     | [{"ID","cds-AEQ77079.1"}, {"Parent","gene-UL48"}, … {"protein_id","AEQ77079.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 103538 | 103543 | null  | -      | null  | [{"ID","id-UL48"}, {"Parent","gene-UL48"}, … {"regulatory_class","polyA_signal_sequence"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 105463 | 106994 | null  | -      | null  | [{"ID","gene-UL49A"}, {"Name","UL49A"}, … {"gene_biotype","protein_coding"}]                                                     | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 106719 | 106994 | null  | -      | 0     | [{"ID","cds-AEQ77081.1"}, {"Parent","gene-UL49A"}, … {"protein_id","AEQ77081.1"}]                                                | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 105463 | 106392 | null  | -      | null  | [{"ID","gene-UL49"}, {"Name","UL49"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 105487 | 106392 | null  | -      | 0     | [{"ID","cds-AEQ77080.1"}, {"Parent","gene-UL49"}, … {"protein_id","AEQ77080.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 105463 | 105468 | null  | -      | null  | [{"ID","id-JN555585.1:105463..105468"}, {"Note","UL49%2C UL49A"}, … {"regulatory_class","polyA_signal_sequence"}]                | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 107011 | 108158 | null  | +      | null  | [{"ID","gene-UL50"}, {"Name","UL50"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 107011 | 108126 | null  | +      | 0     | [{"ID","cds-AEQ77082.1"}, {"Parent","gene-UL50"}, … {"protein_id","AEQ77082.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 108153 | 108158 | null  | +      | null  | [{"ID","id-UL50"}, {"Parent","gene-UL50"}, … {"regulatory_class","polyA_signal_sequence"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 108277 | 109012 | null  | -      | null  | [{"ID","gene-UL51"}, {"Name","UL51"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 108278 | 109012 | null  | -      | 0     | [{"ID","cds-AEQ77083.1"}, {"Parent","gene-UL51"}, … {"protein_id","AEQ77083.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 108277 | 108282 | null  | -      | null  | [{"ID","id-UL51"}, {"Parent","gene-UL51"}, … {"regulatory_class","polyA_signal_sequence"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 109049 | 113449 | null  | +      | null  | [{"ID","gene-UL52"}, {"Name","UL52"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 109049 | 112225 | null  | +      | 0     | [{"ID","cds-AEQ77084.1"}, {"Parent","gene-UL52"}, … {"protein_id","AEQ77084.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 112180 | 113449 | null  | +      | null  | [{"ID","gene-UL53"}, {"Name","UL53"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# ...
# | JN555585.1 | Genbank | TATA_box              | 141143 | 141148 | null  | +      | null  | [{"ID","id-US8"}, {"Parent","gene-US8"}, … {"regulatory_class","TATA_box"}]                                                      | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 142748 | 143697 | null  | +      | null  | [{"ID","gene-US8A"}, {"Name","US8A"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 142748 | 143227 | null  | +      | 0     | [{"ID","cds-AEQ77100.1"}, {"Parent","gene-US8A"}, … {"protein_id","AEQ77100.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 143223 | 143697 | null  | +      | null  | [{"ID","gene-US9"}, {"Name","US9"}, … {"gene_biotype","protein_coding"}]                                                         | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | mRNA                  | 143250 | 143697 | null  | +      | null  | [{"ID","rna-US9"}, {"Parent","gene-US9"}, … {"product","membrane protein US9"}]                                                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | exon                  | 143250 | 143697 | null  | +      | null  | [{"ID","exon-US9-1"}, {"Parent","rna-US9"}, … {"product","membrane protein US9"}]                                                | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 143317 | 143589 | null  | +      | 0     | [{"ID","cds-AEQ77101.1"}, {"Parent","rna-US9"}, … {"protein_id","AEQ77101.1"}]                                                   | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | TATA_box              | 143223 | 143228 | null  | +      | null  | [{"ID","id-US9"}, {"Parent","gene-US9"}, … {"regulatory_class","TATA_box"}]                                                      | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 143672 | 143677 | null  | +      | null  | [{"ID","id-JN555585.1:143672..143677"}, {"Note","US8%2C US8A%2C US9"}, … {"regulatory_class","polyA_signal_sequence"}]           | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | repeat_region         | 143716 | 143868 | null  | +      | null  | [{"ID","id-JN555585.1:143716..143868"}, {"Note","US reiteration set 1"}, … {"rpt_unit_range","143716..143730"}]                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 144124 | 146096 | null  | -      | null  | [{"ID","gene-US12"}, {"Name","US12"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | mRNA                  | 144124 | 146068 | null  | -      | null  | [{"ID","rna-US12"}, {"Parent","gene-US12"}, … {"product","TAP transporter inhibitor ICP47"}]                                     | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | exon                  | 145822 | 146068 | null  | -      | null  | [{"ID","exon-US12-1"}, {"Parent","rna-US12"}, … {"product","TAP transporter inhibitor ICP47"}]                                   | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | exon                  | 144124 | 145653 | null  | -      | null  | [{"ID","exon-US12-2"}, {"Parent","rna-US12"}, … {"product","TAP transporter inhibitor ICP47"}]                                   | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 145316 | 145582 | null  | -      | 0     | [{"ID","cds-AEQ77104.1"}, {"Parent","rna-US12"}, … {"protein_id","AEQ77104.1"}]                                                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | TATA_box              | 146091 | 146096 | null  | -      | null  | [{"ID","id-US12"}, {"Parent","gene-US12"}, … {"regulatory_class","TATA_box"}]                                                    | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 144124 | 145495 | null  | -      | null  | [{"ID","gene-US11"}, {"Name","US11"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | mRNA                  | 144124 | 145469 | null  | -      | null  | [{"ID","rna-US11"}, {"Parent","gene-US11"}, … {"product","tegument protein US11"}]                                               | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | exon                  | 144124 | 145469 | null  | -      | null  | [{"ID","exon-US11-1"}, {"Parent","rna-US11"}, … {"product","tegument protein US11"}]                                             | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 144766 | 145251 | null  | -      | 0     | [{"ID","cds-AEQ77103.1"}, {"Parent","rna-US11"}, … {"protein_id","AEQ77103.1"}]                                                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | TATA_box              | 145490 | 145495 | null  | -      | null  | [{"ID","id-US11"}, {"Parent","gene-US11"}, … {"regulatory_class","TATA_box"}]                                                    | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 144124 | 145198 | null  | -      | null  | [{"ID","gene-US10"}, {"Name","US10"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | mRNA                  | 144124 | 145171 | null  | -      | null  | [{"ID","rna-US10"}, {"Parent","gene-US10"}, … {"product","virion protein US10"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | exon                  | 144124 | 145171 | null  | -      | null  | [{"ID","exon-US10-1"}, {"Parent","rna-US10"}, … {"product","virion protein US10"}]                                               | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 144162 | 145100 | null  | -      | 0     | [{"ID","cds-AEQ77102.1"}, {"Parent","rna-US10"}, … {"protein_id","AEQ77102.1"}]                                                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | TATA_box              | 145193 | 145198 | null  | -      | null  | [{"ID","id-US10"}, {"Parent","gene-US10"}, … {"regulatory_class","TATA_box"}]                                                    | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 144140 | 144145 | null  | -      | null  | [{"ID","id-JN555585.1:144140..144145"}, {"Note","US10%2C US11%2C US12"}, … {"regulatory_class","polyA_signal_sequence"}]         | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | repeat_region         | 144787 | 145003 | null  | +      | null  | [{"ID","id-JN555585.1:144787..145003"}, {"Note","US reiteration set 2"}, … {"rpt_unit_range","144787..144795"}]                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | inverted_repeat       | 145590 | 152222 | null  | +      | null  | [{"ID","id-JN555585.1:145590..152222"}, {"Note","TRS%3B inverted repeat flanking US"}, … {"rpt_type","inverted"}]                | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | repeat_region         | 145681 | 145806 | null  | +      | null  | [{"ID","id-JN555585.1:145681..145806"}, {"Note","RS reiteration set 3"}, … {"rpt_unit_range","145681..145702"}]                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | stem_loop             | 146173 | 146217 | null  | +      | null  | [{"ID","id-JN555585.1:146173..146217"}, {"Note","oriS palindrome"}, {"gbkey","stem_loop"}]                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | gene                  | 146737 | 151023 | null  | +      | null  | [{"ID","gene-RS1-2"}, {"Name","RS1"}, … {"gene_biotype","protein_coding"}]                                                       | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | mRNA                  | 146766 | 151023 | null  | +      | null  | [{"ID","rna-RS1-2"}, {"Parent","gene-RS1-2"}, … {"product","transcriptional regulator ICP4"}]                                    | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | exon                  | 146766 | 151023 | null  | +      | null  | [{"ID","exon-RS1-2-1"}, {"Parent","rna-RS1-2"}, … {"product","transcriptional regulator ICP4"}]                                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | CDS                   | 147066 | 150962 | null  | +      | 0     | [{"ID","cds-AEQ77105.1"}, {"Parent","rna-RS1-2"}, … {"protein_id","AEQ77105.1"}]                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | TATA_box              | 146737 | 146742 | null  | +      | null  | [{"ID","id-RS1-3"}, {"Parent","gene-RS1-2"}, … {"regulatory_class","TATA_box"}]                                                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 151005 | 151010 | null  | +      | null  | [{"ID","id-RS1-4"}, {"Parent","gene-RS1-2"}, … {"regulatory_class","polyA_signal_sequence"}]                                     | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | polyA_signal_sequence | 151046 | 151051 | null  | -      | null  | [{"ID","id-JN555585.1:151046..151051"}, {"Note","LAT"}, … {"regulatory_class","polyA_signal_sequence"}]                          | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | repeat_region         | 151052 | 151384 | null  | +      | null  | [{"ID","id-JN555585.1:151052..151384"}, {"Note","RS reiteration set 2"}, … {"rpt_unit_range","151052..151068"}]                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | repeat_region         | 151486 | 151624 | null  | +      | null  | [{"ID","id-JN555585.1:151486..151624"}, {"Note","RS reiteration set 1"}, … {"rpt_unit_range","151486..151501"}]                  | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | repeat_region         | 151824 | 152222 | null  | +      | null  | [{"ID","id-JN555585.1:151824..152222"}, {"Note","'a' sequence"}, … {"rpt_type","terminal"}]                                      | downloaded_gff/groupI_GCA_000859985.2.gff |
# | JN555585.1 | Genbank | repeat_region         | 151921 | 152143 | null  | +      | null  | [{"ID","id-JN555585.1:151921..152143"}, {"Note","'a' sequence reiteration set"}, … {"rpt_unit_range","151921..151932"}]          | downloaded_gff/groupI_GCA_000859985.2.gff |
# Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
#
# --- Statistics ---
# Total rows: 316
# Total columns: 10
#
# Feature types:
# | type                  | count |
# | ---                   | ---   |
# | str                   | u32   |
# |-----------------------|-------|
# | CDS                   | 82    |
# | gene                  | 79    |
# | polyA_signal_sequence | 53    |
# | exon                  | 27    |
# | repeat_region         | 26    |
# | TATA_box              | 19    |
# | mRNA                  | 17    |
# | inverted_repeat       | 5     |
# | stem_loop             | 3     |
# | ncRNA                 | 2     |
# | sequence_feature      | 2     |
# | region                | 1     |
# CompletedProcess(args=['gff2parquet', 'print', 'downloaded_gff/groupI_GCA_000859985.2.gff', '--stats'], returncode=0, stdout='| seqid      | source  | type                  | start  | end    | score | strand | phase | attributes                                                                                                                       | source_file                               |\n| ---        | ---     | ---                   | ---    | ---    | ---   | ---    | ---   | ---                                                                                                                              | ---                                       |\n| str        | str     | str                   | u32    | u32    | f32   | str    | u32   | list[struct[2]]                                                                                                                  | str                                       |\n|------------|---------|-----------------------|--------|--------|-------|--------|-------|----------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------|\n| JN555585.1 | Genbank | region                | 1      | 152222 | null  | +      | null  | [{"ID","JN555585.1:1..152222"}, {"Dbxref","taxon:10298"}, … {"strain","17"}]                                                     | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | inverted_repeat       | 1      | 9213   | null  | +      | null  | [{"ID","id-JN555585.1:1..9213"}, {"Note","TRL%3B inverted repeat flanking UL"}, … {"rpt_type","inverted"}]                       | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | gene                  | 1      | 7569   | null  | -      | null  | [{"ID","gene-LAT"}, {"Name","LAT"}, … {"start_range",".,1"}]                                                                     | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | ncRNA                 | 1      | 7569   | null  | -      | null  | [{"ID","rna-LAT"}, {"Parent","gene-LAT"}, … {"start_range",".,1"}]                                                               | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | exon                  | 6910   | 7569   | null  | -      | null  | [{"ID","exon-LAT-1"}, {"Parent","rna-LAT"}, … {"product","LAT"}]                                                                 | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | exon                  | 1      | 4953   | null  | -      | null  | [{"ID","exon-LAT-2"}, {"Parent","rna-LAT"}, … {"start_range",".,1"}]                                                             | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | repeat_region         | 1      | 399    | null  | +      | null  | [{"ID","id-JN555585.1:1..399"}, {"Note","\'a\' sequence"}, … {"rpt_type","terminal"}]                                              | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | repeat_region         | 98     | 320    | null  | +      | null  | [{"ID","id-JN555585.1:98..320"}, {"Note","\'a\' sequence reiteration set"}, … {"rpt_unit_range","98..109"}]                        | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | gene                  | 513    | 1540   | null  | +      | null  | [{"ID","gene-RL1"}, {"Name","RL1"}, … {"gene_biotype","protein_coding"}]                                                         | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | CDS                   | 513    | 1259   | null  | +      | 0     | [{"ID","cds-AEQ77029.1"}, {"Parent","gene-RL1"}, … {"protein_id","AEQ77029.1"}]                                                  | downloaded_gff/groupI_GCA_000859985.2.gff |\n| JN555585.1 | Genbank | repeat_region         | 988    | 1040   | null  | +      | null  | [{"ID","id-RL1"}, {"Note", ...

# %% [markdown]
# ### Filter and display only CDS features
# bonus, using csv (tsv actually) format for the output

# %%
run_gff2parquet([
    "print",
    str(GFF_DIR / "groupI_GCA_000859985.2.gff"),
    "--type", "CDS",
    "--head", "5",
    "--columns", "seqid,type,start,end,strand",
    "--format", "csv"
])
# Out:
# Running: gff2parquet print downloaded_gff/groupI_GCA_000859985.2.gff --type CDS --head 5 --columns seqid,type,start,end,strand --format csv
# seqid	type	start	end	strand
# JN555585.1	CDS	513	1259	+
# JN555585.1	CDS	2262	2318	+
# JN555585.1	CDS	3084	3750	+
# JN555585.1	CDS	3887	5490	+
# JN555585.1	CDS	9338	10012	+
# Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
# CompletedProcess(args=['gff2parquet', 'print', 'downloaded_gff/groupI_GCA_000859985.2.gff', '--type', 'CDS', '--head', '5', '--columns', 'seqid,type,start,end,strand', '--format', 'csv'], returncode=0, stdout='seqid\ttype\tstart\tend\tstrand\nJN555585.1\tCDS\t513\t1259\t+\nJN555585.1\tCDS\t2262\t2318\t+\nJN555585.1\tCDS\t3084\t3750\t+\nJN555585.1\tCDS\t3887\t5490\t+\nJN555585.1\tCDS\t9338\t10012\t+\n', stderr="Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'\nScanning: downloaded_gff/groupI_GCA_000859985.2.gff\n")

# %% [markdown]
# ## 2. Convert Command - GFF to Parquet
# whow

# %%
run_gff2parquet([
    "convert",
    str(GFF_DIR / "groupI_GCA_000859985.2.gff"),
    "-o", str(OUTPUT_DIR / "groupI.parquet")
])
# Out:
# Running: gff2parquet convert downloaded_gff/groupI_GCA_000859985.2.gff -o test_outputs/groupI.parquet
# Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
# Writing Parquet to test_outputs/groupI.parquet...
# Done!
# CompletedProcess(args=['gff2parquet', 'convert', 'downloaded_gff/groupI_GCA_000859985.2.gff', '-o', 'test_outputs/groupI.parquet'], returncode=0, stdout='', stderr="Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'\nScanning: downloaded_gff/groupI_GCA_000859985.2.gff\nWriting Parquet to test_outputs/groupI.parquet...\nDone!\n")

# %% [markdown]
# ### Convert with column normalization
# "normalization" - in a very opioniotated way, coherce colums and attributes that to fit specification.
# Converts the items in each column below into field names (e.g. `begin` -> `start`).
#
# | Start | End | Sequence ID | Score | Source | Type |
# |-------|-----|-------------|-------|--------|------|
# | begin | to | qseqid | bitscore | tool | feature |
# | from | seq_to | sequence_ID | bit_score | method | annotation |
# | seq_from | query_end | contig_id | bits | db | category |
# | query_start | qend | contig | evalue | database |  |
# | qstart |  | query | e_value |  |  |
# |  |  | id |  |  |  |
# |  |  | name |  |  |  |
#
# I use this when stacking multiple annotation results - like hmmsearch or blast, from different tabular formats. It ain't perfect, I know. If you want to do something more sophisticated, you can use the `normalize_column_names` function in the `gff2parquet/cli.py` script - personally I think dumping everything into the attributes column is even more of a mess, but that's just me.

# %%
run_gff2parquet([
    "convert",
    str(GFF_DIR / "groupII_GCA_031099375.1.gff"),
    "--normalize",
    "-o", str(OUTPUT_DIR / "groupII_normalized.parquet")
])
print(f"headers from reading the output file: {pq.read_metadata(OUTPUT_DIR / 'groupII_normalized.parquet')}")
# Out:
# Running: gff2parquet convert downloaded_gff/groupII_GCA_031099375.1.gff --normalize -o test_outputs/groupII_normalized.parquet
# headers from reading the output file: <pyarrow._parquet.FileMetaData object at 0x7f4140053e50>
#   created_by: Polars
#   num_columns: 11
#   num_rows: 7
#   num_row_groups: 1
#   format_version: 1.0
#   serialized_size: 2050
# Found 1 file(s) matching pattern 'downloaded_gff/groupII_GCA_031099375.1.gff'
# Scanning: downloaded_gff/groupII_GCA_031099375.1.gff
# Normalizing column names...
# Writing Parquet to test_outputs/groupII_normalized.parquet...
# Done!

# %% [markdown]
# ### Convert with coordinate shifting (0-based to 1-based)

# %%
run_gff2parquet([
    "convert",
    str(GFF_DIR / "groupIII_GCA_000880735.1.gff"),
    "--shift-start", "1",
    "-o", str(OUTPUT_DIR / "groupIII_shifted.parquet")
])
# Out:
# Running: gff2parquet convert downloaded_gff/groupIII_GCA_000880735.1.gff --shift-start 1 -o test_outputs/groupIII_shifted.parquet
# Found 1 file(s) matching pattern 'downloaded_gff/groupIII_GCA_000880735.1.gff'
# Scanning: downloaded_gff/groupIII_GCA_000880735.1.gff
# Shifting coordinates (start: 1, end: 0)...
# Writing Parquet to test_outputs/groupIII_shifted.parquet...
# Done!
# CompletedProcess(args=['gff2parquet', 'convert', 'downloaded_gff/groupIII_GCA_000880735.1.gff', '--shift-start', '1', '-o', 'test_outputs/groupIII_shifted.parquet'], returncode=0, stdout='', stderr="Found 1 file(s) matching pattern 'downloaded_gff/groupIII_GCA_000880735.1.gff'\nScanning: downloaded_gff/groupIII_GCA_000880735.1.gff\nShifting coordinates (start: 1, end: 0)...\nWriting Parquet to test_outputs/groupIII_shifted.parquet...\nDone!\n")

# %% [markdown]
# ## 3. Merge Command - Combine Multiple GFF Files
#
# Merge all GFF files from a directory into a single file.

# %%
run_gff2parquet([
    "merge",
    str(GFF_DIR / "*.gff"),
    "-o", str(OUTPUT_DIR / "all_merged.parquet")
])
print(f"total number of records from reading the output file: {pq.read_metadata(OUTPUT_DIR / 'all_merged.parquet').num_rows}")
# Out:
# Running: gff2parquet merge downloaded_gff/*.gff -o test_outputs/all_merged.parquet
# total number of records from reading the output file: 444
# Merging 1 input pattern(s)...
# Found 8 file(s) matching pattern 'downloaded_gff/*.gff'
# Scanning: downloaded_gff/groupIII_GCA_000880735.1.gff
# Scanning: downloaded_gff/groupII_GCA_031099375.1.gff
# Scanning: downloaded_gff/groupIV_GCA_031102545.1.gff
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
# Scanning: downloaded_gff/groupVII_GCA_031171435.1.gff
# Scanning: downloaded_gff/groupVI_GCA_000864765.1.gff
# Scanning: downloaded_gff/groupV_GCA_053294245.1.gff
# Scanning: downloaded_gff/groupcirular_rna_GCA_050924405.1.gff
# Writing Parquet to test_outputs/all_merged.parquet...
# Done!

# %% [markdown]
# ### Merge with normalization and output as csv

# %%
run_gff2parquet([
    "merge",
    str(GFF_DIR / "group*.gff"),
    "--normalize",
    "-f", "csv",  # Changed from "pyarrow" to "csv"
    "-o", str(OUTPUT_DIR / "merged_normalized.csv")
])
# Out:
# Running: gff2parquet merge downloaded_gff/group*.gff --normalize -f csv -o test_outputs/merged_normalized.csv
# Merging 1 input pattern(s)...
# Found 8 file(s) matching pattern 'downloaded_gff/group*.gff'
# Scanning: downloaded_gff/groupIII_GCA_000880735.1.gff
# Scanning: downloaded_gff/groupII_GCA_031099375.1.gff
# Scanning: downloaded_gff/groupIV_GCA_031102545.1.gff
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
# Scanning: downloaded_gff/groupVII_GCA_031171435.1.gff
# Scanning: downloaded_gff/groupVI_GCA_000864765.1.gff
# Scanning: downloaded_gff/groupV_GCA_053294245.1.gff
# Scanning: downloaded_gff/groupcirular_rna_GCA_050924405.1.gff
# Normalizing column names...
# Writing CSV...
# Done!
# CompletedProcess(args=['gff2parquet', 'merge', 'downloaded_gff/group*.gff', '--normalize', '-f', 'csv', '-o', 'test_outputs/merged_normalized.csv'], returncode=0, stdout='', stderr="Merging 1 input pattern(s)...\nFound 8 file(s) matching pattern 'downloaded_gff/group*.gff'\nScanning: downloaded_gff/groupIII_GCA_000880735.1.gff\nScanning: downloaded_gff/groupII_GCA_031099375.1.gff\nScanning: downloaded_gff/groupIV_GCA_031102545.1.gff\nScanning: downloaded_gff/groupI_GCA_000859985.2.gff\nScanning: downloaded_gff/groupVII_GCA_031171435.1.gff\nScanning: downloaded_gff/groupVI_GCA_000864765.1.gff\nScanning: downloaded_gff/groupV_GCA_053294245.1.gff\nScanning: downloaded_gff/groupcirular_rna_GCA_050924405.1.gff\nNormalizing column names...\nWriting CSV...\nDone!\n")

# %% [markdown]
# ## 4. Filter Command - Extract Specific Features

# %% [markdown]
# ### Filter CDS features only

# %%
run_gff2parquet([
    "filter",
    str(GFF_DIR / "groupI_GCA_000859985.2.gff"),
    "--type", "CDS",
    "-o", str(OUTPUT_DIR / "cds_only.parquet")
])
# Out:
# Running: gff2parquet filter downloaded_gff/groupI_GCA_000859985.2.gff --type CDS -o test_outputs/cds_only.parquet
# Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
# Applying filters...
# Writing Parquet to test_outputs/cds_only.parquet...
# Done!
# CompletedProcess(args=['gff2parquet', 'filter', 'downloaded_gff/groupI_GCA_000859985.2.gff', '--type', 'CDS', '-o', 'test_outputs/cds_only.parquet'], returncode=0, stdout='', stderr="Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'\nScanning: downloaded_gff/groupI_GCA_000859985.2.gff\nApplying filters...\nWriting Parquet to test_outputs/cds_only.parquet...\nDone!\n")

# %% [markdown]
# ### Filter by minimum length

# %%
run_gff2parquet([
    "filter",
    str(GFF_DIR / "groupI_GCA_000859985.2.gff"),
    "--type", "CDS",
    "--min-length", "500",
    "-o", str(OUTPUT_DIR / "long_cds.csv"),
    "-f", "csv"
])
# Out:
# Running: gff2parquet filter downloaded_gff/groupI_GCA_000859985.2.gff --type CDS --min-length 500 -o test_outputs/long_cds.csv -f csv
# Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
# Applying filters...
# Writing CSV...
# Done!
# CompletedProcess(args=['gff2parquet', 'filter', 'downloaded_gff/groupI_GCA_000859985.2.gff', '--type', 'CDS', '--min-length', '500', '-o', 'test_outputs/long_cds.csv', '-f', 'csv'], returncode=0, stdout='', stderr="Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'\nScanning: downloaded_gff/groupI_GCA_000859985.2.gff\nApplying filters...\nWriting CSV...\nDone!\n")

# %% [markdown]
# ### Filter by strand and length range

# %%
run_gff2parquet([
    "filter",
    str(GFF_DIR / "groupI_GCA_000859985.2.gff"),
    "--type", "gene",
    "--strand", "+",
    "--min-length", "300",
    "--max-length", "3000",
    "-o", str(OUTPUT_DIR / "filtered_genes.parquet")
])
# Out:
# Running: gff2parquet filter downloaded_gff/groupI_GCA_000859985.2.gff --type gene --strand + --min-length 300 --max-length 3000 -o test_outputs/filtered_genes.parquet
# Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
# Applying filters...
# Writing Parquet to test_outputs/filtered_genes.parquet...
# Done!
# CompletedProcess(args=['gff2parquet', 'filter', 'downloaded_gff/groupI_GCA_000859985.2.gff', '--type', 'gene', '--strand', '+', '--min-length', '300', '--max-length', '3000', '-o', 'test_outputs/filtered_genes.parquet'], returncode=0, stdout='', stderr="Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'\nScanning: downloaded_gff/groupI_GCA_000859985.2.gff\nApplying filters...\nWriting Parquet to test_outputs/filtered_genes.parquet...\nDone!\n")

# %% [markdown]
# ## 5. Split Command - Separate by Column Values
#
# Split GFF data into separate files based on column values.

# %% [markdown]
# ### Split by feature type

# %%
run_gff2parquet([
    "split",
    str(GFF_DIR / "groupI_GCA_000859985.2.gff"),
    "--column", "type",
    "--output-dir", str(OUTPUT_DIR / "split_by_type"),
    "-f", "parquet"
])
# Out:
# Running: gff2parquet split downloaded_gff/groupI_GCA_000859985.2.gff --column type --output-dir test_outputs/split_by_type -f parquet
# Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
# Splitting into 12 files by 'type'
# Wrote 19 rows to test_outputs/split_by_type/type_TATA_box.parquet
# Wrote 17 rows to test_outputs/split_by_type/type_mRNA.parquet
# Wrote 53 rows to test_outputs/split_by_type/type_polyA_signal_sequence.parquet
# Wrote 27 rows to test_outputs/split_by_type/type_exon.parquet
# Wrote 82 rows to test_outputs/split_by_type/type_CDS.parquet
# Wrote 1 rows to test_outputs/split_by_type/type_region.parquet
# Wrote 2 rows to test_outputs/split_by_type/type_ncRNA.parquet
# Wrote 26 rows to test_outputs/split_by_type/type_repeat_region.parquet
# Wrote 5 rows to test_outputs/split_by_type/type_inverted_repeat.parquet
# Wrote 3 rows to test_outputs/split_by_type/type_stem_loop.parquet
# Wrote 79 rows to test_outputs/split_by_type/type_gene.parquet
# Wrote 2 rows to test_outputs/split_by_type/type_sequence_feature.parquet
# Done!
# CompletedProcess(args=['gff2parquet', 'split', 'downloaded_gff/groupI_GCA_000859985.2.gff', '--column', 'type', '--output-dir', 'test_outputs/split_by_type', '-f', 'parquet'], returncode=0, stdout='', stderr="Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'\nScanning: downloaded_gff/groupI_GCA_000859985.2.gff\nSplitting into 12 files by 'type'\nWrote 19 rows to test_outputs/split_by_type/type_TATA_box.parquet\nWrote 17 rows to test_outputs/split_by_type/type_mRNA.parquet\nWrote 53 rows to test_outputs/split_by_type/type_polyA_signal_sequence.parquet\nWrote 27 rows to test_outputs/split_by_type/type_exon.parquet\nWrote 82 rows to test_outputs/split_by_type/type_CDS.parquet\nWrote 1 rows to test_outputs/split_by_type/type_region.parquet\nWrote 2 rows to test_outputs/split_by_type/type_ncRNA.parquet\nWrote 26 rows to test_outputs/split_by_type/type_repeat_region.parquet\nWrote 5 rows to test_outputs/split_by_type/type_inverted_repeat.parquet\nWrote 3 rows to test_outputs/split_by_type/type_stem_loop.parquet\nWrote 79 rows to test_outputs/split_by_type/type_gene.parquet\nWrote 2 rows to test_outputs/split_by_type/type_sequence_feature.parquet\nDone!\n")

# %% [markdown]
# ### Split by sequence ID (chromosome/contig)

# %%
run_gff2parquet([
    "split",
    str(GFF_DIR / "groupI_GCA_000859985.2.gff"),
    "--column", "seqid",
    "--output-dir", str(OUTPUT_DIR / "split_by_seqid"),
    "-f", "gff"
])
# Out:
# Running: gff2parquet split downloaded_gff/groupI_GCA_000859985.2.gff --column seqid --output-dir test_outputs/split_by_seqid -f gff
# Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
# Splitting into 1 files by 'seqid'
# Wrote 316 rows to test_outputs/split_by_seqid/seqid_JN555585.1.gff3
# Done!
# CompletedProcess(args=['gff2parquet', 'split', 'downloaded_gff/groupI_GCA_000859985.2.gff', '--column', 'seqid', '--output-dir', 'test_outputs/split_by_seqid', '-f', 'gff'], returncode=0, stdout='', stderr="Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'\nScanning: downloaded_gff/groupI_GCA_000859985.2.gff\nSplitting into 1 files by 'seqid'\nWrote 316 rows to test_outputs/split_by_seqid/seqid_JN555585.1.gff3\nDone!\n")

# %% [markdown]
# ## 6. Extract Command - Get Sequences from FASTA

# %% [markdown]
# ### Extract CDS sequences as nucleotides

# %%
run_gff2parquet([
    "extract",
    str(GFF_DIR / "groupI_GCA_000859985.2.gff"),
    str(FASTA_DIR / "groupI_GCA_000859985.2.fna"),
    "--type", "CDS",
    "-o", str(OUTPUT_DIR / "cds_sequences.fasta")
])
# Out:
# Running: gff2parquet extract downloaded_gff/groupI_GCA_000859985.2.gff downloaded_fasta/groupI_GCA_000859985.2.fna --type CDS -o test_outputs/cds_sequences.fasta
# Loading GFF from: downloaded_gff/groupI_GCA_000859985.2.gff
# Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
# Applying filters...
# Found 1 FASTA file(s)
# Loading FASTA sequences...
#   Reading: downloaded_fasta/groupI_GCA_000859985.2.fna
#
# 0rows [00:00, ?rows/s]
# 1rows [00:00, 189.43rows/s]
# Extracting 82 features...
# Extracted 82 sequences
# Done!
# CompletedProcess(args=['gff2parquet', 'extract', 'downloaded_gff/groupI_GCA_000859985.2.gff', 'downloaded_fasta/groupI_GCA_000859985.2.fna', '--type', 'CDS', '-o', 'test_outputs/cds_sequences.fasta'], returncode=0, stdout='', stderr="Loading GFF from: downloaded_gff/groupI_GCA_000859985.2.gff\nFound 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'\nScanning: downloaded_gff/groupI_GCA_000859985.2.gff\nApplying filters...\nFound 1 FASTA file(s)\nLoading FASTA sequences...\n  Reading: downloaded_fasta/groupI_GCA_000859985.2.fna\n\n0rows [00:00, ?rows/s]\n1rows [00:00, 189.43rows/s]\nExtracting 82 features...\nExtracted 82 sequences\nDone!\n")

# %% [markdown]
# ### Extract and translate CDS to proteins

# %%
run_gff2parquet([
    "extract",
    str(GFF_DIR / "groupI_GCA_000859985.2.gff"),
    str(FASTA_DIR / "groupI_GCA_000859985.2.fna"),
    "--type", "CDS",
    "--outfmt", "amino",
    "--genetic-code", "11",
    "-o", str(OUTPUT_DIR / "cds_proteins.fasta")
])
# Out:
# Running: gff2parquet extract downloaded_gff/groupI_GCA_000859985.2.gff downloaded_fasta/groupI_GCA_000859985.2.fna --type CDS --outfmt amino --genetic-code 11 -o test_outputs/cds_proteins.fasta
# Loading GFF from: downloaded_gff/groupI_GCA_000859985.2.gff
# Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
# Applying filters...
# Found 1 FASTA file(s)
# Loading FASTA sequences...
#   Reading: downloaded_fasta/groupI_GCA_000859985.2.fna
#
# 0rows [00:00, ?rows/s]
# 1rows [00:00, 65.08rows/s]
# Extracting 82 features...
# Extracted 82 sequences
# Done!
# CompletedProcess(args=['gff2parquet', 'extract', 'downloaded_gff/groupI_GCA_000859985.2.gff', 'downloaded_fasta/groupI_GCA_000859985.2.fna', '--type', 'CDS', '--outfmt', 'amino', '--genetic-code', '11', '-o', 'test_outputs/cds_proteins.fasta'], returncode=0, stdout='', stderr="Loading GFF from: downloaded_gff/groupI_GCA_000859985.2.gff\nFound 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'\nScanning: downloaded_gff/groupI_GCA_000859985.2.gff\nApplying filters...\nFound 1 FASTA file(s)\nLoading FASTA sequences...\n  Reading: downloaded_fasta/groupI_GCA_000859985.2.fna\n\n0rows [00:00, ?rows/s]\n1rows [00:00, 65.08rows/s]\nExtracting 82 features...\nExtracted 82 sequences\nDone!\n")

# %% [markdown]
# ### Extract long CDS and translate

# %%
run_gff2parquet([
    "extract",
    str(GFF_DIR / "groupI_GCA_000859985.2.gff"),
    str(FASTA_DIR / "groupI_GCA_000859985.2.fna"),
    "--type", "CDS",
    "--min-length", "500",
    "--outfmt", "amino",
    "-o", str(OUTPUT_DIR / "long_proteins.fasta")
])
# Out:
# Running: gff2parquet extract downloaded_gff/groupI_GCA_000859985.2.gff downloaded_fasta/groupI_GCA_000859985.2.fna --type CDS --min-length 500 --outfmt amino -o test_outputs/long_proteins.fasta
# Loading GFF from: downloaded_gff/groupI_GCA_000859985.2.gff
# Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
# Applying filters...
# Found 1 FASTA file(s)
# Loading FASTA sequences...
#   Reading: downloaded_fasta/groupI_GCA_000859985.2.fna
#
# 0rows [00:00, ?rows/s]
# 1rows [00:00, 221.42rows/s]
# Extracting 71 features...
# Extracted 71 sequences
# Done!
# CompletedProcess(args=['gff2parquet', 'extract', 'downloaded_gff/groupI_GCA_000859985.2.gff', 'downloaded_fasta/groupI_GCA_000859985.2.fna', '--type', 'CDS', '--min-length', '500', '--outfmt', 'amino', '-o', 'test_outputs/long_proteins.fasta'], returncode=0, stdout='', stderr="Loading GFF from: downloaded_gff/groupI_GCA_000859985.2.gff\nFound 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'\nScanning: downloaded_gff/groupI_GCA_000859985.2.gff\nApplying filters...\nFound 1 FASTA file(s)\nLoading FASTA sequences...\n  Reading: downloaded_fasta/groupI_GCA_000859985.2.fna\n\n0rows [00:00, ?rows/s]\n1rows [00:00, 221.42rows/s]\nExtracting 71 features...\nExtracted 71 sequences\nDone!\n")

# %% [markdown]
# ### Extract from multiple genomes

# %%
run_gff2parquet([
    "extract",
    str(GFF_DIR / "groupI*.gff"),
    str(FASTA_DIR / "groupI_GCA_000859985.2.fna"),
    str(FASTA_DIR / "groupII_GCA_031099375.1.fna"),
    "--type", "CDS",
    "--outfmt", "amino",
    "-f", "parquet",
    "-o", str(OUTPUT_DIR / "multi_genome_proteins.parquet")
])
# Out:
# Running: gff2parquet extract downloaded_gff/groupI*.gff downloaded_fasta/groupI_GCA_000859985.2.fna downloaded_fasta/groupII_GCA_031099375.1.fna --type CDS --outfmt amino -f parquet -o test_outputs/multi_genome_proteins.parquet
# Loading GFF from: downloaded_gff/groupI*.gff
# Found 4 file(s) matching pattern 'downloaded_gff/groupI*.gff'
# Scanning: downloaded_gff/groupIII_GCA_000880735.1.gff
# Scanning: downloaded_gff/groupII_GCA_031099375.1.gff
# Scanning: downloaded_gff/groupIV_GCA_031102545.1.gff
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
# Applying filters...
# Found 2 FASTA file(s)
# Loading FASTA sequences...
#   Reading: downloaded_fasta/groupI_GCA_000859985.2.fna
#
# 0rows [00:00, ?rows/s]
# 1rows [00:00, 217.38rows/s]
#   Reading: downloaded_fasta/groupII_GCA_031099375.1.fna
#
# 0rows [00:00, ?rows/s]
# 1rows [00:00, 583.68rows/s]
# Extracting 101 features...
# Extracted 88 sequences
# Done!
# CompletedProcess(args=['gff2parquet', 'extract', 'downloaded_gff/groupI*.gff', 'downloaded_fasta/groupI_GCA_000859985.2.fna', 'downloaded_fasta/groupII_GCA_031099375.1.fna', '--type', 'CDS', '--outfmt', 'amino', '-f', 'parquet', '-o', 'test_outputs/multi_genome_proteins.parquet'], returncode=0, stdout='', stderr="Loading GFF from: downloaded_gff/groupI*.gff\nFound 4 file(s) matching pattern 'downloaded_gff/groupI*.gff'\nScanning: downloaded_gff/groupIII_GCA_000880735.1.gff\nScanning: downloaded_gff/groupII_GCA_031099375.1.gff\nScanning: downloaded_gff/groupIV_GCA_031102545.1.gff\nScanning: downloaded_gff/groupI_GCA_000859985.2.gff\nApplying filters...\nFound 2 FASTA file(s)\nLoading FASTA sequences...\n  Reading: downloaded_fasta/groupI_GCA_000859985.2.fna\n\n0rows [00:00, ?rows/s]\n1rows [00:00, 217.38rows/s]\n  Reading: downloaded_fasta/groupII_GCA_031099375.1.fna\n\n0rows [00:00, ?rows/s]\n1rows [00:00, 583.68rows/s]\nExtracting 101 features...\nExtracted 88 sequences\nDone!\n")

# %% [markdown]
# ### extract from multiple genomes using glob pattern

# %%
run_gff2parquet([
    "extract",
    str(GFF_DIR / "groupI*.gff"),
    str(FASTA_DIR / "group*.fna"),  # Glob pattern
    "--type", "CDS",
    "-o", str(OUTPUT_DIR / "all_cds.fasta")
])

# Or multiple patterns:
run_gff2parquet([
    "extract",
    str(GFF_DIR / "*.gff"),
    str(FASTA_DIR / "groupI*.fna"),
    str(FASTA_DIR / "groupII*.fna"),
    "--type", "CDS",
    "--outfmt", "amino",
    "-o", str(OUTPUT_DIR / "selected_proteins.fasta")
])
# Out:
# Running: gff2parquet extract downloaded_gff/groupI*.gff downloaded_fasta/group*.fna --type CDS -o test_outputs/all_cds.fasta
# Loading GFF from: downloaded_gff/groupI*.gff
# Found 4 file(s) matching pattern 'downloaded_gff/groupI*.gff'
# Scanning: downloaded_gff/groupIII_GCA_000880735.1.gff
# Scanning: downloaded_gff/groupII_GCA_031099375.1.gff
# Scanning: downloaded_gff/groupIV_GCA_031102545.1.gff
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
# Applying filters...
# Found 8 FASTA file(s)
# Loading FASTA sequences...
#   Reading: downloaded_fasta/groupIII_GCA_000880735.1.fna
#
# 0rows [00:00, ?rows/s]
# 11rows [00:00, 2295.39rows/s]
#   Reading: downloaded_fasta/groupII_GCA_031099375.1.fna
#
# 0rows [00:00, ?rows/s]
# 1rows [00:00, 536.91rows/s]
#   Reading: downloaded_fasta/groupIV_GCA_031102545.1.fna
#
# 0rows [00:00, ?rows/s]
# 1rows [00:00, 937.69rows/s]
#   Reading: downloaded_fasta/groupI_GCA_000859985.2.fna
#
# 0rows [00:00, ?rows/s]
# 1rows [00:00, 304.09rows/s]
#   Reading: downloaded_fasta/groupVII_GCA_031171435.1.fna
#
# 0rows [00:00, ?rows/s]
# 1rows [00:00, 963.54rows/s]
#   Reading: downloaded_fasta/groupVI_GCA_000864765.1.fna
#
# 0rows [00:00, ?rows/s]
# 1rows [00:00, 224.19rows/s]
#   Reading: downloaded_fasta/groupV_GCA_053294245.1.fna
#
# 0rows [00:00, ?rows/s]
# 8rows [00:00, 7792.48rows/s]
#   Reading: downloaded_fasta/groupcirular_rna_GCA_050924405.1.fna
#
# 0rows [00:00, ?rows/s]
# 1rows [00:00, 976.78rows/s]
# Extracting 101 features...
# Extracted 101 sequences
# Done!
# Running: gff2parquet extract downloaded_gff/*.gff downloaded_fasta/groupI*.fna downloaded_fasta/groupII*.fna --type CDS --outfmt amino -o test_outputs/selected_proteins.fasta
# Loading GFF from: downloaded_gff/*.gff
# Found 8 file(s) matching pattern 'downloaded_gff/*.gff'
# Scanning: downloaded_gff/groupIII_GCA_000880735.1.gff
# Scanning: downloaded_gff/groupII_GCA_031099375.1.gff
# Scanning: downloaded_gff/groupIV_GCA_031102545.1.gff
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
# Scanning: downloaded_gff/groupVII_GCA_031171435.1.gff
# Scanning: downloaded_gff/groupVI_GCA_000864765.1.gff
# Scanning: downloaded_gff/groupV_GCA_053294245.1.gff
# Scanning: downloaded_gff/groupcirular_rna_GCA_050924405.1.gff
# Applying filters...
# Found 6 FASTA file(s)
# Loading FASTA sequences...
#   Reading: downloaded_fasta/groupIII_GCA_000880735.1.fna
#
# 0rows [00:00, ?rows/s]
# 11rows [00:00, 2615.79rows/s]
#   Reading: downloaded_fasta/groupII_GCA_031099375.1.fna
#
# 0rows [00:00, ?rows/s]
# 1rows [00:00, 870.01rows/s]
#   Reading: downloaded_fasta/groupIV_GCA_031102545.1.fna
#
# 0rows [00:00, ?rows/s]
# 1rows [00:00, 956.95rows/s]
#   Reading: downloaded_fasta/groupI_GCA_000859985.2.fna
#
# 0rows [00:00, ?rows/s]
# 1rows [00:00, 437.13rows/s]
#   Reading: downloaded_fasta/groupIII_GCA_000880735.1.fna
#
# 0rows [00:00, ?rows/s]
# 11rows [00:00, 9973.49rows/s]
#   Reading: downloaded_fasta/groupII_GCA_031099375.1.fna
#
# 0rows [00:00, ?rows/s]
# 1rows [00:00, 1018.78rows/s]
# Extracting 133 features...
# Extracted 119 sequences
# Done!
# CompletedProcess(args=['gff2parquet', 'extract', 'downloaded_gff/*.gff', 'downloaded_fasta/groupI*.fna', 'downloaded_fasta/groupII*.fna', '--type', 'CDS', '--outfmt', 'amino', '-o', 'test_outputs/selected_proteins.fasta'], returncode=0, stdout='', stderr="Loading GFF from: downloaded_gff/*.gff\nFound 8 file(s) matching pattern 'downloaded_gff/*.gff'\nScanning: downloaded_gff/groupIII_GCA_000880735.1.gff\nScanning: downloaded_gff/groupII_GCA_031099375.1.gff\nScanning: downloaded_gff/groupIV_GCA_031102545.1.gff\nScanning: downloaded_gff/groupI_GCA_000859985.2.gff\nScanning: downloaded_gff/groupVII_GCA_031171435.1.gff\nScanning: downloaded_gff/groupVI_GCA_000864765.1.gff\nScanning: downloaded_gff/groupV_GCA_053294245.1.gff\nScanning: downloaded_gff/groupcirular_rna_GCA_050924405.1.gff\nApplying filters...\nFound 6 FASTA file(s)\nLoading FASTA sequences...\n  Reading: downloaded_fasta/groupIII_GCA_000880735.1.fna\n\n0rows [00:00, ?rows/s]\n11rows [00:00, 2615.79rows/s]\n  Reading: downloaded_fasta/groupII_GCA_031099375.1.fna\n\n0rows [00:00, ?rows/s]\n1rows [00:00, 870.01rows/s]\n  Reading: downloaded_fasta/groupIV_GCA_031102545.1.fna\n\n0rows [00:00, ?rows/s]\n1rows [00:00, 956.95rows/s]\n  Reading: downloaded_fasta/groupI_GCA_000859985.2.fna\n\n0rows [00:00, ?rows/s]\n1rows [00:00, 437.13rows/s]\n  Reading: downloaded_fasta/groupIII_GCA_000880735.1.fna\n\n0rows [00:00, ?rows/s]\n11rows [00:00, 9973.49rows/s]\n  Reading: downloaded_fasta/groupII_GCA_031099375.1.fna\n\n0rows [00:00, ?rows/s]\n1rows [00:00, 1018.78rows/s]\nExtracting 133 features...\nExtracted 119 sequences\nDone!\n")

# %% [markdown]
# ## 7. Complex Workflows - Combining Commands

# %% [markdown]
# ### Workflow 1: Merge → Filter → Extract

# %%
# Step 1: Merge all annotations
run_gff2parquet([
    "merge",
    str(GFF_DIR / "group[I-IV]*.gff"),
    "-o", str(OUTPUT_DIR / "workflow1_merged.parquet")
])

# Step 2: Filter for long CDS
run_gff2parquet([
    "filter",
    str(OUTPUT_DIR / "workflow1_merged.parquet"),
    "--type", "CDS",
    "--min-length", "600",
    "-o", str(OUTPUT_DIR / "workflow1_filtered.gff"),
    "-f", "gff"
])

# Step 3: Extract and translate
run_gff2parquet([
    "extract",
    str(OUTPUT_DIR / "workflow1_filtered.gff"),
    str(FASTA_DIR / "groupI_GCA_000859985.2.fna"),
    str(FASTA_DIR / "groupII_GCA_031099375.1.fna"),
    str(FASTA_DIR / "groupIII_GCA_000880735.1.fna"),
    str(FASTA_DIR / "groupIV_GCA_031102545.1.fna"),
    "--outfmt", "amino",
    "-o", str(OUTPUT_DIR / "workflow1_proteins.fasta")
])
# Out:
# Running: gff2parquet merge downloaded_gff/group[I-IV]*.gff -o test_outputs/workflow1_merged.parquet
# Merging 1 input pattern(s)...
# Found 7 file(s) matching pattern 'downloaded_gff/group[I-IV]*.gff'
# Scanning: downloaded_gff/groupIII_GCA_000880735.1.gff
# Scanning: downloaded_gff/groupII_GCA_031099375.1.gff
# Scanning: downloaded_gff/groupIV_GCA_031102545.1.gff
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
# Scanning: downloaded_gff/groupVII_GCA_031171435.1.gff
# Scanning: downloaded_gff/groupVI_GCA_000864765.1.gff
# Scanning: downloaded_gff/groupV_GCA_053294245.1.gff
# Writing Parquet to test_outputs/workflow1_merged.parquet...
# Done!
# Running: gff2parquet filter test_outputs/workflow1_merged.parquet --type CDS --min-length 600 -o test_outputs/workflow1_filtered.gff -f gff
# Found 1 file(s) matching pattern 'test_outputs/workflow1_merged.parquet'
# Scanning: test_outputs/workflow1_merged.parquet
# Applying filters...
# Writing GFF3 to test_outputs/workflow1_filtered.gff...
# Done!
# Running: gff2parquet extract test_outputs/workflow1_filtered.gff downloaded_fasta/groupI_GCA_000859985.2.fna downloaded_fasta/groupII_GCA_031099375.1.fna downloaded_fasta/groupIII_GCA_000880735.1.fna downloaded_fasta/groupIV_GCA_031102545.1.fna --outfmt amino -o test_outputs/workflow1_proteins.fasta
# Loading GFF from: test_outputs/workflow1_filtered.gff
# Found 1 file(s) matching pattern 'test_outputs/workflow1_filtered.gff'
# Scanning: test_outputs/workflow1_filtered.gff
# Found 4 FASTA file(s)
# Loading FASTA sequences...
#   Reading: downloaded_fasta/groupI_GCA_000859985.2.fna
#
# 0rows [00:00, ?rows/s]
# 1rows [00:00, 178.90rows/s]
#   Reading: downloaded_fasta/groupII_GCA_031099375.1.fna
#
# 0rows [00:00, ?rows/s]
# 1rows [00:00, 413.88rows/s]
#   Reading: downloaded_fasta/groupIII_GCA_000880735.1.fna
#
# 0rows [00:00, ?rows/s]
# 11rows [00:00, 6403.52rows/s]
#   Reading: downloaded_fasta/groupIV_GCA_031102545.1.fna
#
# 0rows [00:00, ?rows/s]
# 1rows [00:00, 885.81rows/s]
# Extracting 96 features...
# Extracted 82 sequences
# Done!
# CompletedProcess(args=['gff2parquet', 'extract', 'test_outputs/workflow1_filtered.gff', 'downloaded_fasta/groupI_GCA_000859985.2.fna', 'downloaded_fasta/groupII_GCA_031099375.1.fna', 'downloaded_fasta/groupIII_GCA_000880735.1.fna', 'downloaded_fasta/groupIV_GCA_031102545.1.fna', '--outfmt', 'amino', '-o', 'test_outputs/workflow1_proteins.fasta'], returncode=0, stdout='', stderr="Loading GFF from: test_outputs/workflow1_filtered.gff\nFound 1 file(s) matching pattern 'test_outputs/workflow1_filtered.gff'\nScanning: test_outputs/workflow1_filtered.gff\nFound 4 FASTA file(s)\nLoading FASTA sequences...\n  Reading: downloaded_fasta/groupI_GCA_000859985.2.fna\n\n0rows [00:00, ?rows/s]\n1rows [00:00, 178.90rows/s]\n  Reading: downloaded_fasta/groupII_GCA_031099375.1.fna\n\n0rows [00:00, ?rows/s]\n1rows [00:00, 413.88rows/s]\n  Reading: downloaded_fasta/groupIII_GCA_000880735.1.fna\n\n0rows [00:00, ?rows/s]\n11rows [00:00, 6403.52rows/s]\n  Reading: downloaded_fasta/groupIV_GCA_031102545.1.fna\n\n0rows [00:00, ?rows/s]\n1rows [00:00, 885.81rows/s]\nExtracting 96 features...\nExtracted 82 sequences\nDone!\n")

# %% [markdown]
# ### Workflow 2: Filter by type → Split by seqid

# %%
# Filter for genes
run_gff2parquet([
    "filter",
    str(GFF_DIR / "groupI_GCA_000859985.2.gff"),
    "--type", "gene",
    "-o", str(OUTPUT_DIR / "workflow2_genes.parquet")
])

# Split by seqid 
run_gff2parquet([
    "split",
    str(OUTPUT_DIR / "workflow2_genes.parquet"),
    "--column", "seqid",
    "--output-dir", str(OUTPUT_DIR / "workflow2_by_chromosome"),
    "-f", "gff"
])
# Out:
# Running: gff2parquet filter downloaded_gff/groupI_GCA_000859985.2.gff --type gene -o test_outputs/workflow2_genes.parquet
# Found 1 file(s) matching pattern 'downloaded_gff/groupI_GCA_000859985.2.gff'
# Scanning: downloaded_gff/groupI_GCA_000859985.2.gff
# Applying filters...
# Writing Parquet to test_outputs/workflow2_genes.parquet...
# Done!
# Running: gff2parquet split test_outputs/workflow2_genes.parquet --column seqid --output-dir test_outputs/workflow2_by_chromosome -f gff
# Found 1 file(s) matching pattern 'test_outputs/workflow2_genes.parquet'
# Scanning: test_outputs/workflow2_genes.parquet
# Splitting into 1 files by 'seqid'
# Wrote 79 rows to test_outputs/workflow2_by_chromosome/seqid_JN555585.1.gff3
# Done!
# CompletedProcess(args=['gff2parquet', 'split', 'test_outputs/workflow2_genes.parquet', '--column', 'seqid', '--output-dir', 'test_outputs/workflow2_by_chromosome', '-f', 'gff'], returncode=0, stdout='', stderr="Found 1 file(s) matching pattern 'test_outputs/workflow2_genes.parquet'\nScanning: test_outputs/workflow2_genes.parquet\nSplitting into 1 files by 'seqid'\nWrote 79 rows to test_outputs/workflow2_by_chromosome/seqid_JN555585.1.gff3\nDone!\n")

# %% [markdown]
# ## 8. Verification - Check Outputs
#
# Verify that output files were created successfully.

# %%
print("Output files created:")
for root, dirs, files in os.walk(OUTPUT_DIR):
    level = root.replace(str(OUTPUT_DIR), '').count(os.sep)
    indent = ' ' * 2 * level
    print(f'{indent}{os.path.basename(root)}/')
    subindent = ' ' * 2 * (level + 1)
    for file in files:
        size = os.path.getsize(os.path.join(root, file))*1e-6
        print(f'{subindent}{file} ({size:,} MB)')
# Out:
# Output files created:
# test_outputs/
#   all_cds.fasta (157,604 bytes)
#   all_merged.parquet (17,531 bytes)
#   cds_only.parquet (7,119 bytes)
#   cds_proteins.fasta (44,014 bytes)
#   cds_sequences.fasta (126,208 bytes)
#   filtered_genes.parquet (5,161 bytes)
#   groupI.parquet (12,825 bytes)
#   groupIII_shifted.parquet (5,468 bytes)
#   groupII_normalized.parquet (4,509 bytes)
#   long_cds.csv (17,342 bytes)
#   long_proteins.fasta (42,551 bytes)
#   merged_normalized.csv (89,091 bytes)
#   multi_genome_proteins.parquet (711,170 bytes)
#   selected_proteins.fasta (63,492 bytes)
#   workflow1_filtered.gff (18,341 bytes)
#   workflow1_merged.parquet (17,277 bytes)
#   workflow1_proteins.fasta (52,149 bytes)
#   workflow2_genes.parquet (5,544 bytes)
#   split_by_seqid/
#     seqid_JN555585.1.gff3 (48,783 bytes)
#   split_by_type/
#     type_CDS.parquet (7,119 bytes)
#     type_TATA_box.parquet (4,593 bytes)
#     type_exon.parquet (4,862 bytes)
#     type_gene.parquet (5,544 bytes)
#     type_inverted_repeat.parquet (4,381 bytes)
#     type_mRNA.parquet (4,613 bytes)
#     type_ncRNA.parquet (4,142 bytes)
#     type_polyA_signal_sequence.parquet (5,660 bytes)
#     type_region.parquet (4,454 bytes)
#     type_repeat_region.parquet (5,061 bytes)
#     type_sequence_feature.parquet (4,321 bytes)
#     type_stem_loop.parquet (4,270 bytes)
#   workflow2_by_chromosome/
#     seqid_JN555585.1.gff3 (10,065 bytes)

# %% [markdown]
# ## Summary
#
# This notebook demonstrated:
# - **print**: Inspecting GFF data and statistics
# - **convert**: Converting GFF to Parquet/CSV with normalization and coordinate shifting
# - **merge**: Combining multiple GFF files
# - **filter**: Extracting features by type, length, strand, etc.
# - **split**: Separating data into multiple files by column values
# - **extract**: Extracting and optionally translating sequences from FASTA
# - Complex multi-step workflows combining multiple commands
